# %% [markdown]
# ## dependency

# %%
# !pip install ConfigSpace
# Out:
# Requirement already satisfied: ConfigSpace in /usr/local/lib/python3.10/dist-packages (1.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ConfigSpace) (1.26.4)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from ConfigSpace) (3.2.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from ConfigSpace) (1.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from ConfigSpace) (4.12.2)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from ConfigSpace) (10.5.0)
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# ## random search

# %%
import ConfigSpace
import numpy as np
import typing


class RandomSearch(object):

    def __init__(self, config_space: ConfigSpace.ConfigurationSpace):
        self.config_space = config_space

    def initialize(self, capital_phi: typing.List[typing.Tuple[typing.Dict, float]]) -> None:
        pass

    def select_configuration(self) -> ConfigSpace.Configuration:
        return self.config_space.sample_configuration(size=None)

    def update_runs(self, run: typing.Tuple[typing.Dict, float]):
        pass

# %% [markdown]
# ## surrogate model

# %%
import ConfigSpace

import pandas as pd
import sklearn.impute
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from scipy.stats import spearmanr


class SurrogateModel:

    def __init__(self, config_space):
        self.config_space = config_space
        self.df = None
        self.model = None

    def fit(self, df):
        """
        Receives a data frame, in which each column (except for the last two) represents a hyperparameter, the
        penultimate column represents the anchor size, and the final column represents the performance.

        :param df: the dataframe with performances
        :return: Does not return anything, but stores the trained model in self.model
        """
        self.df = df
        X = df.iloc[:, :-1]
        y = df.iloc[:, -1]

        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

        # Identify categorical and numerical columns
        categorical_features = X.select_dtypes(include=['object', 'category']).columns.tolist()
        numerical_features = X.select_dtypes(include=['number']).columns.tolist()

        numeric_transformer = Pipeline(steps=[
            ('imputer', SimpleImputer(strategy='mean')),
            ('scaler', StandardScaler())
        ])
        categorical_transformer = Pipeline(steps=[
            ('imputer', SimpleImputer(strategy='most_frequent')),
            ('onehot', OneHotEncoder(handle_unknown='ignore'))
        ])
        # Create the ColumnTransformer to apply the appropriate transformations to each column
        preprocessor = ColumnTransformer(
            transformers=[
                ('num', numeric_transformer, numerical_features),
                ('cat', categorical_transformer, categorical_features)
            ])

        self.model = Pipeline(steps=[
            ('preprocessor', preprocessor),
            ('regressor', RandomForestRegressor(n_estimators=1000, random_state=40))
        ])
        self.model.fit(X_train, y_train)

        y_pred = self.model.predict(X_test)
        mse = mean_squared_error(y_test, y_pred)
        r2 = r2_score(y_test, y_pred)
        corr, _ = spearmanr(y_test, y_pred)
        print(f"External surrogate Model Evaluation: - MSE: {mse:.4f}, R2: {r2:.4f}")
        print(f"Spearman Correlation: {corr:.4f}")

    def predict(self, theta_new):
        """
        Predicts the performance of a given configuration theta_new

        :param theta_new: a dict, where each key represents the hyperparameter (or anchor)
        :return: float, the predicted performance of theta new (which can be considered the ground truth)
        """
        config_space = dict(self.config_space)
        for config in config_space:
            if config not in theta_new:
                theta_new[config] = config_space[config].default_value

        theta_new_df = pd.DataFrame([theta_new])
        X_test = theta_new_df[self.df.keys()[:-1]]
        return float(self.model.predict(X_test)[0])

# %% [markdown]
# ## smbo

# %%
import ConfigSpace
import numpy as np
import pandas as pd
import typing

from sklearn.pipeline import Pipeline
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, WhiteKernel,ConstantKernel as C
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from scipy.stats import norm
import scipy.stats as sps

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score


class SequentialModelBasedOptimization(object):

    def __init__(self, config_space):
        """
        Initializes empty variables for the model, the list of runs (capital R), and the incumbent
        (theta_inc being the best found hyperparameters, theta_inc_performance being the performance
        associated with it)
        """
        self.config_space = config_space
        self.model = None
        self.R = []
        self.theta_inc = None
        self.theta_inc_performance = None

    def initialize(self, capital_phi: typing.List[typing.Tuple[typing.Dict, float]]) -> None:
        """
        Initializes the model with a set of initial configurations, before it can make recommendations
        which configurations are in good regions. Note that we are minimising (lower values are preferred)

        :param capital_phi: a list of tuples, each tuple being a configuration and the performance (typically,
        error rate)
        """
        self.R = capital_phi

        for config, performance in capital_phi:
            if self.theta_inc is None or performance < self.theta_inc_performance:
                self.theta_inc = config
                self.theta_inc_performance = performance

        self.fit_model()

    def fit_model(self) -> None:
        """
        Fits the internal surrogate model on the complete run list.
        """
        # Rs = []
        # for (c, p) in self.R:
        #     c = pd.DataFrame([c])
        #     p = [p]
        #     p = pd.DataFrame(p, columns=['score'])
        #     R_ = pd.concat([c, p], axis=1)
        #     Rs.append(R_)
        # df = pd.concat(Rs, axis=0)
        # X = df.iloc[:, :-1]
        # y = df.iloc[:, -1]
        df = pd.concat([pd.DataFrame([config]).assign(score=performance) for config, performance in self.R], axis=0)
        X = df.iloc[:, :-1]
        y = df['score']

        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

        # Identify categorical and numerical columns
        categorical_features = X.select_dtypes(include=['object']).columns
        numerical_features = X.select_dtypes(include=['number']).columns

        numeric_transformer = Pipeline(steps=[
            ('imputer', SimpleImputer(strategy='mean')),
            ('scaler', StandardScaler())
        ])
        categorical_transformer = Pipeline(steps=[
            ('imputer', SimpleImputer(strategy='most_frequent')),
            ('onehot', OneHotEncoder())
        ])
        # Create the ColumnTransformer to apply the appropriate transformations to each column
        preprocessor = ColumnTransformer(
            transformers=[
                ('num', numeric_transformer, numerical_features),
                ('cat', categorical_transformer, categorical_features)
            ])

        # GaussianProcessRegressor as internal surrogate model
        kernel = C(1.0, (1e-3, 1e3)) * RBF(length_scale=1.0) + WhiteKernel(noise_level=1e-5)
        self.model = Pipeline(steps=[
            ('preprocessor', preprocessor),
            ('regressor', GaussianProcessRegressor(kernel=kernel, alpha=1e-4,
                                                   normalize_y=True, random_state=40,
                                                   n_restarts_optimizer=30))
        ])
        self.model.fit(X_train, y_train)

        pred = self.model.predict(X_test)
        mse = mean_squared_error(y_test, pred)
        r2 = r2_score(y_test, pred)
        print(f"Internal Surrogate Model Evaluation: - MSE: {mse:.4f}, R2: {r2:.4f}")

        self.theta_inc = X.iloc[np.argmin(y)]
        self.theta_inc_performance = y.iloc[np.argmin(y)]

    def select_configuration(self) -> ConfigSpace.Configuration:
        """
        Determines which configurations are good, based on the internal surrogate model.
        Note that we are minimizing the error, but the expected improvement takes into account that.
        Therefore, we are maximizing expected improvement here.

        :return: A size n vector, same size as each element representing the EI of a given
        configuration
        """
        num_candidates = 200
        config_space = list(self.config_space.values())
        random_configs = [dict(self.config_space.sample_configuration()) for _ in range(num_candidates)]
        for configs in random_configs:
            for config in config_space:
                if config.name not in configs.keys():
                    configs[config.name] = config.default_value

        configs_df = pd.DataFrame(random_configs)
        e = self.expected_improvement(self.model, self.theta_inc_performance, configs_df)
        best_index  = np.argmax(e)
        return random_configs[best_index]

    @staticmethod
    def expected_improvement(model_pipeline: Pipeline, f_star: float, theta: np.array) -> np.array:
        """
        Acquisition function that determines which configurations are good and which
        are not good.

        :param model_pipeline: The internal surrogate model (should be fitted already)
        :param f_star: The current incumbent (theta_inc)
        :param theta: A (n, m) array, each column represents a hyperparameter and each row
        represents a configuration
        :return: A size n vector, same size as each element representing the EI of a given
        configuration
        """
        mu, sigma = model_pipeline.predict(theta, return_std=True)
        improvement = f_star - mu

        with np.errstate(divide='warn'):
            z = np.where(sigma > 0, improvement / sigma, 0)
            ei = improvement * norm.cdf(z) + sigma * norm.pdf(z)
            ei[sigma == 0.0] = 0.0

        return ei.ravel()

    def update_runs(self, run: typing.Tuple[typing.Dict, float]):
        """
        After a configuration has been selected and ran, it will be added to the run list
        (so that the model can be trained on it during the next iterations).

        :param run: A tuple (configuration, performance) where performance is error rate
        """
        config, performance = run
        self.R.append(run)

        if performance < self.theta_inc_performance:
            self.theta_inc = config
            self.theta_inc_performance = performance

        self.fit_model()

# %% [markdown]
# ## successive halving

# %%
import ConfigSpace
import numpy as np
import pandas as pd

class SuccessiveHalving(object):
    def __init__(self, config_space: ConfigSpace.ConfigurationSpace, max_anchor_size, halving_factor: int = 2):
        self.config_space = config_space
        self.halving_factor = halving_factor
        self.max_anchor_size = max_anchor_size
        self.best_performance = []
        self.best = np.inf
        self.total_anchor = [0]

    def run(self, surrogate_model):
        total_performance = {}
        # anchor size to be 10% of data
        current_anchor = 25
        configs = [dict(self.config_space.sample_configuration()) for _ in range(64)]
        while(current_anchor<=self.max_anchor_size):
            self.total_anchor.append(current_anchor)
            performances = []
            m = len(configs)

            for config in configs:
                for hp in list(self.config_space.values()):
                    if hp.name not in config.keys():
                        config[hp.name] = hp.default_value
                config['anchor_size'] = current_anchor

                performance = surrogate_model.predict(config)
                performances.append(performance)

            total_performance['M'+str(current_anchor)] = performances
            performances = np.array(performances)
            performances_sorted = np.argsort(performances)
            num = int(m/self.halving_factor)

            configs = [configs[index] for index in performances_sorted[:num]]
            current_anchor *= self.halving_factor

        p = total_performance.get(list(total_performance.keys())[-1])[0]
        if p < self.best:
            self.best = p
            self.best_performance.append(total_performance)
        return self.best

# %% [markdown]
# ## experiment

# %%
import argparse
import ConfigSpace
import matplotlib.pyplot as plt
import pandas as pd
# from random_search import RandomSearch
# from surrogate_model import SurrogateModel
# from smbo import SequentialModelBasedOptimization
# from successive_halving import SuccessiveHalving


def parse_args():
    parser = argparse.ArgumentParser()
    parser.add_argument('--config_space_file', type=str, default='lcdb_config_space_knn.json')
    parser.add_argument('--configurations_performance_file', type=str, default='lcdb_configs.csv')
    # max_anchor_size: connected to the configurations_performance_file. The max value upon which anchors are sampled
    parser.add_argument('--max_anchor_size', type=int, default=1600)
    parser.add_argument('--num_iterations', type=int, default=50)

    args, _ = parser.parse_known_args()
    return args
    # return parser.parse_args()


def run(args):
    df = pd.read_csv(args.configurations_performance_file)
    config_space = ConfigSpace.ConfigurationSpace.from_json(args.config_space_file)
    random_search = RandomSearch(config_space)

    df_list = []
    df_1 = pd.read_csv(args.configurations_performance_file)
    df_2 = pd.read_csv('config_performances_dataset-1457.csv')
    df_3 = pd.read_csv('config_performances_dataset-11.csv')
    df_4 = pd.read_csv('config_performances_dataset-6.csv')
    df_list.append(df_1)
    df_list.append(df_2)
    df_list.append(df_3)
    df_list.append(df_4)
    for df in df_list:
        smbo = SequentialModelBasedOptimization(config_space)
        sh = SuccessiveHalving(config_space,args.max_anchor_size, halving_factor=2)

        surrogate_model_rs = SurrogateModel(config_space)
        surrogate_model_smbo = SurrogateModel(config_space)
        surrogate_model_sh = SurrogateModel(config_space)
        surrogate_model_rs.fit(df)
        surrogate_model_smbo.fit(df)
        surrogate_model_sh.fit(df)

        configs = [dict(config_space.sample_configuration()) for _ in range(200)]
        for config in configs:
            config['anchor_size'] = args.max_anchor_size
            config['score'] = surrogate_model_smbo.predict(config)
        # configs_ = configs.copy()
        # for c in configs_:
        #     c = c.pop('anchor_size')
        # variables = list(df.keys())
        # variables.remove('anchor_size')
        # df_config = pd.DataFrame([[i[j] for j in variables] for i in configs_], columns=variables)
        # m, n = df_config.shape
        # initial_runs = []
        # for _, row in df_config.iterrows():
        #     config = dict(row.head(n-1))
        #     p = row['score']
        #     initial_runs.append((config, p))
        df_config = pd.DataFrame([{k: v for k, v in config.items() if k != 'anchor_size'} for config in configs])
        initial_runs = [(row.drop('score').to_dict(), row['score']) for _, row in df_config.iterrows()]
        smbo.initialize(initial_runs)

        results = {
            'random_search': [1.0],
            'smbo': [1.0],
            'successive_halving': [1.0]
        }

        for idx in range(args.num_iterations):
            theta_new_rs = dict(random_search.select_configuration())
            theta_new_rs['anchor_size'] = args.max_anchor_size
            performance_rs = surrogate_model_rs.predict(theta_new_rs)
            # ensure to only record improvements
            results['random_search'].append(min(results['random_search'][-1], performance_rs))
            random_search.update_runs((theta_new_rs, performance_rs))

            theta_new_smbo = dict(smbo.select_configuration())
            theta_new_smbo['anchor_size'] = args.max_anchor_size
            theta_new_smbo_update = theta_new_smbo.copy()
            performance_smbo = surrogate_model_smbo.predict(theta_new_smbo)
            results['smbo'].append(min(results['smbo'][-1], performance_smbo))
            del theta_new_smbo_update['anchor_size']
            smbo.update_runs((theta_new_smbo_update, performance_smbo))

            performance_sh = sh.run(surrogate_model_sh)
            results['successive_halving'].append(min(results['successive_halving'][-1], performance_sh))
        print('Random Search: ', min(results['random_search']))
        print('SMBO: ', min(results['smbo']))
        print('Successive Halving: ', min(results['successive_halving']))

        plt.plot(range(len(results['random_search'])), results['random_search'], label='random search')
        plt.plot(range(len(results['smbo'])), results['smbo'], label='smbo')
        plt.plot(range(len(results['successive_halving'])), results['successive_halving'], label='successive halving')
        plt.legend()
        plt.yscale('log')
        plt.show()


if __name__ == '__main__':
    run(parse_args())
# Out:
# External surrogate Model Evaluation: - MSE: 0.0003, R2: 0.9925
# Spearman Correlation: 0.9965
# External surrogate Model Evaluation: - MSE: 0.0003, R2: 0.9940
# Spearman Correlation: 0.9957
# External surrogate Model Evaluation: - MSE: 0.0004, R2: 0.9921
# Spearman Correlation: 0.9960
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.4366
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.3218
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.6351
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.5332
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.5079
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.4839
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.5125
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.6652
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.5831
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: -0.0366
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.4686
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.7868
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.4939
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.5264
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.4615
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.7391
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.6006
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.6123
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.2932
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.5508
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.6028
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.4668
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.6336
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: -0.0658
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.1969
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.6519
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.2709
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.5541
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.4317
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.6130
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.6656
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.4592
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.6351
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.4391
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.2031
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.4453
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.6088
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.5121
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.5263
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.4101
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.6117
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.6295
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.6190
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.3637
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.6263
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.5471
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.5336
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.4616
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.5246
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.4237
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.6064
# Random Search:  0.1541863999999995
# SMBO:  0.15292079999999872
# Successive Halving:  0.1540653999999998
# External surrogate Model Evaluation: - MSE: 0.0000, R2: 0.9969
# Spearman Correlation: 0.9889
# External surrogate Model Evaluation: - MSE: 0.0000, R2: 0.9958
# Spearman Correlation: 0.9911
# External surrogate Model Evaluation: - MSE: 0.0001, R2: 0.9951
# Spearman Correlation: 0.9909
# Internal Surrogate Model Evaluation: - MSE: 0.0005, R2: 0.9344
# Internal Surrogate Model Evaluation: - MSE: 0.0007, R2: 0.8828
# Internal Surrogate Model Evaluation: - MSE: 0.0007, R2: 0.9126
# Internal Surrogate Model Evaluation: - MSE: 0.0004, R2: 0.8997
# Internal Surrogate Model Evaluation: - MSE: 0.0005, R2: 0.8779
# Internal Surrogate Model Evaluation: - MSE: 0.0004, R2: 0.9402
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9156
# Internal Surrogate Model Evaluation: - MSE: 0.0004, R2: 0.9367
# Internal Surrogate Model Evaluation: - MSE: 0.0007, R2: 0.9159
# Internal Surrogate Model Evaluation: - MSE: 0.0004, R2: 0.9500
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9017
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9351
# Internal Surrogate Model Evaluation: - MSE: 0.0004, R2: 0.9483
# Internal Surrogate Model Evaluation: - MSE: 0.0005, R2: 0.9550
# Internal Surrogate Model Evaluation: - MSE: 0.0005, R2: 0.9302
# Internal Surrogate Model Evaluation: - MSE: 0.0004, R2: 0.9512
# Internal Surrogate Model Evaluation: - MSE: 0.0005, R2: 0.9569
# Internal Surrogate Model Evaluation: - MSE: 0.0005, R2: 0.9585
# Internal Surrogate Model Evaluation: - MSE: 0.0004, R2: 0.9558
# Internal Surrogate Model Evaluation: - MSE: 0.0005, R2: 0.9476
# Internal Surrogate Model Evaluation: - MSE: 0.0003, R2: 0.9745
# Internal Surrogate Model Evaluation: - MSE: 0.0009, R2: 0.9042
# Internal Surrogate Model Evaluation: - MSE: 0.0004, R2: 0.9463
# Internal Surrogate Model Evaluation: - MSE: 0.0007, R2: 0.9361
# Internal Surrogate Model Evaluation: - MSE: 0.0004, R2: 0.9568
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9385
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9372
# Internal Surrogate Model Evaluation: - MSE: 0.0005, R2: 0.9372
# Internal Surrogate Model Evaluation: - MSE: 0.0005, R2: 0.9543
# Internal Surrogate Model Evaluation: - MSE: 0.0004, R2: 0.9553
# Internal Surrogate Model Evaluation: - MSE: 0.0004, R2: 0.9739
# Internal Surrogate Model Evaluation: - MSE: 0.0005, R2: 0.9570
# Internal Surrogate Model Evaluation: - MSE: 0.0005, R2: 0.9551
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9574
# Internal Surrogate Model Evaluation: - MSE: 0.0004, R2: 0.9568
# Internal Surrogate Model Evaluation: - MSE: 0.0003, R2: 0.9686
# Internal Surrogate Model Evaluation: - MSE: 0.0005, R2: 0.9577
# Internal Surrogate Model Evaluation: - MSE: 0.0004, R2: 0.9534
# Internal Surrogate Model Evaluation: - MSE: 0.0004, R2: 0.9598
# Internal Surrogate Model Evaluation: - MSE: 0.0004, R2: 0.9537
# Internal Surrogate Model Evaluation: - MSE: 0.0004, R2: 0.9626
# Internal Surrogate Model Evaluation: - MSE: 0.0004, R2: 0.9624
# Internal Surrogate Model Evaluation: - MSE: 0.0003, R2: 0.9594
# Internal Surrogate Model Evaluation: - MSE: 0.0005, R2: 0.9522
# Internal Surrogate Model Evaluation: - MSE: 0.0003, R2: 0.9726
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9448
# Internal Surrogate Model Evaluation: - MSE: 0.0005, R2: 0.9495
# Internal Surrogate Model Evaluation: - MSE: 0.0002, R2: 0.9781
# Internal Surrogate Model Evaluation: - MSE: 0.0004, R2: 0.9684
# /usr/local/lib/python3.10/dist-packages/sklearn/gaussian_process/_gpr.py:659: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   _check_optimize_result("lbfgs", opt_res)
# Internal Surrogate Model Evaluation: - MSE: 0.0004, R2: 0.9689
# Internal Surrogate Model Evaluation: - MSE: 0.0003, R2: 0.9653
# Random Search:  0.541070333333327
# SMBO:  0.5141973333333278
# Successive Halving:  0.5150439999999946
# External surrogate Model Evaluation: - MSE: 0.0000, R2: 0.9975
# Spearman Correlation: 0.9979
# External surrogate Model Evaluation: - MSE: 0.0000, R2: 0.9986
# Spearman Correlation: 0.9983
# External surrogate Model Evaluation: - MSE: 0.0000, R2: 0.9983
# Spearman Correlation: 0.9984
# Internal Surrogate Model Evaluation: - MSE: 0.0031, R2: 0.4169
# Internal Surrogate Model Evaluation: - MSE: 0.0021, R2: 0.4986
# Internal Surrogate Model Evaluation: - MSE: 0.0024, R2: 0.6347
# Internal Surrogate Model Evaluation: - MSE: 0.0021, R2: 0.6253
# Internal Surrogate Model Evaluation: - MSE: 0.0027, R2: 0.5670
# Internal Surrogate Model Evaluation: - MSE: 0.0036, R2: 0.4836
# Internal Surrogate Model Evaluation: - MSE: 0.0019, R2: 0.3804
# Internal Surrogate Model Evaluation: - MSE: 0.0033, R2: 0.5519
# Internal Surrogate Model Evaluation: - MSE: 0.0025, R2: 0.5860
# Internal Surrogate Model Evaluation: - MSE: 0.0024, R2: 0.3489
# Internal Surrogate Model Evaluation: - MSE: 0.0023, R2: 0.6408
# Internal Surrogate Model Evaluation: - MSE: 0.0023, R2: 0.5710
# Internal Surrogate Model Evaluation: - MSE: 0.0015, R2: 0.7182
# Internal Surrogate Model Evaluation: - MSE: 0.0018, R2: 0.6470
# Internal Surrogate Model Evaluation: - MSE: 0.0022, R2: 0.6565
# Internal Surrogate Model Evaluation: - MSE: 0.0019, R2: 0.6740
# Internal Surrogate Model Evaluation: - MSE: 0.0030, R2: 0.4536
# Internal Surrogate Model Evaluation: - MSE: 0.0026, R2: 0.5451
# Internal Surrogate Model Evaluation: - MSE: 0.0019, R2: 0.6896
# Internal Surrogate Model Evaluation: - MSE: 0.0019, R2: 0.6375
# Internal Surrogate Model Evaluation: - MSE: 0.0020, R2: 0.5560
# Internal Surrogate Model Evaluation: - MSE: 0.0025, R2: 0.6369
# Internal Surrogate Model Evaluation: - MSE: 0.0018, R2: 0.6211
# Internal Surrogate Model Evaluation: - MSE: 0.0025, R2: 0.5718
# Internal Surrogate Model Evaluation: - MSE: 0.0024, R2: 0.6472
# Internal Surrogate Model Evaluation: - MSE: 0.0022, R2: 0.6139
# Internal Surrogate Model Evaluation: - MSE: 0.0029, R2: 0.4992
# Internal Surrogate Model Evaluation: - MSE: 0.0032, R2: 0.5910
# Internal Surrogate Model Evaluation: - MSE: 0.0017, R2: 0.6142
# Internal Surrogate Model Evaluation: - MSE: 0.0026, R2: 0.6310
# Internal Surrogate Model Evaluation: - MSE: 0.0013, R2: 0.7343
# Internal Surrogate Model Evaluation: - MSE: 0.0028, R2: 0.4011
# Internal Surrogate Model Evaluation: - MSE: 0.0029, R2: 0.5603
# Internal Surrogate Model Evaluation: - MSE: 0.0020, R2: 0.6909
# Internal Surrogate Model Evaluation: - MSE: 0.0016, R2: 0.7003
# Internal Surrogate Model Evaluation: - MSE: 0.0015, R2: 0.6842
# Internal Surrogate Model Evaluation: - MSE: 0.0016, R2: 0.6867
# Internal Surrogate Model Evaluation: - MSE: 0.0023, R2: 0.6192
# Internal Surrogate Model Evaluation: - MSE: 0.0020, R2: 0.6857
# Internal Surrogate Model Evaluation: - MSE: 0.0022, R2: 0.6748
# Internal Surrogate Model Evaluation: - MSE: 0.0023, R2: 0.5521
# Internal Surrogate Model Evaluation: - MSE: 0.0019, R2: 0.6440
# Internal Surrogate Model Evaluation: - MSE: 0.0021, R2: 0.6414
# Internal Surrogate Model Evaluation: - MSE: 0.0023, R2: 0.6793
# Internal Surrogate Model Evaluation: - MSE: 0.0019, R2: 0.6409
# Internal Surrogate Model Evaluation: - MSE: 0.0017, R2: 0.7547
# Internal Surrogate Model Evaluation: - MSE: 0.0021, R2: 0.7028
# Internal Surrogate Model Evaluation: - MSE: 0.0027, R2: 0.6172
# Internal Surrogate Model Evaluation: - MSE: 0.0018, R2: 0.6876
# Internal Surrogate Model Evaluation: - MSE: 0.0026, R2: 0.5563
# Internal Surrogate Model Evaluation: - MSE: 0.0028, R2: 0.5695
# Random Search:  0.026864516129032196
# SMBO:  0.024990322580645378
# Successive Halving:  0.025170967741935817
# External surrogate Model Evaluation: - MSE: 0.0000, R2: 0.9998
# Spearman Correlation: 0.9998
# External surrogate Model Evaluation: - MSE: 0.0000, R2: 0.9998
# Spearman Correlation: 0.9998
# External surrogate Model Evaluation: - MSE: 0.0000, R2: 0.9998
# Spearman Correlation: 0.9998
# Internal Surrogate Model Evaluation: - MSE: 0.0008, R2: 0.8814
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9526
# Internal Surrogate Model Evaluation: - MSE: 0.0007, R2: 0.9176
# Internal Surrogate Model Evaluation: - MSE: 0.0017, R2: 0.8038
# Internal Surrogate Model Evaluation: - MSE: 0.0008, R2: 0.9404
# Internal Surrogate Model Evaluation: - MSE: 0.0008, R2: 0.9241
# Internal Surrogate Model Evaluation: - MSE: 0.0013, R2: 0.8818
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9367
# Internal Surrogate Model Evaluation: - MSE: 0.0011, R2: 0.8321
# Internal Surrogate Model Evaluation: - MSE: 0.0004, R2: 0.9559
# Internal Surrogate Model Evaluation: - MSE: 0.0005, R2: 0.9492
# Internal Surrogate Model Evaluation: - MSE: 0.0009, R2: 0.9144
# Internal Surrogate Model Evaluation: - MSE: 0.0009, R2: 0.9258
# Internal Surrogate Model Evaluation: - MSE: 0.0013, R2: 0.8587
# Internal Surrogate Model Evaluation: - MSE: 0.0010, R2: 0.9212
# Internal Surrogate Model Evaluation: - MSE: 0.0011, R2: 0.8850
# Internal Surrogate Model Evaluation: - MSE: 0.0010, R2: 0.9073
# Internal Surrogate Model Evaluation: - MSE: 0.0009, R2: 0.8995
# Internal Surrogate Model Evaluation: - MSE: 0.0008, R2: 0.9394
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9399
# Internal Surrogate Model Evaluation: - MSE: 0.0008, R2: 0.9270
# Internal Surrogate Model Evaluation: - MSE: 0.0011, R2: 0.9040
# Internal Surrogate Model Evaluation: - MSE: 0.0005, R2: 0.9281
# Internal Surrogate Model Evaluation: - MSE: 0.0008, R2: 0.9089
# Internal Surrogate Model Evaluation: - MSE: 0.0004, R2: 0.9511
# Internal Surrogate Model Evaluation: - MSE: 0.0007, R2: 0.9032
# Internal Surrogate Model Evaluation: - MSE: 0.0007, R2: 0.9095
# Internal Surrogate Model Evaluation: - MSE: 0.0010, R2: 0.8926
# Internal Surrogate Model Evaluation: - MSE: 0.0011, R2: 0.8919
# Internal Surrogate Model Evaluation: - MSE: 0.0007, R2: 0.9057
# Internal Surrogate Model Evaluation: - MSE: 0.0008, R2: 0.9013
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9363
# Internal Surrogate Model Evaluation: - MSE: 0.0009, R2: 0.8458
# Internal Surrogate Model Evaluation: - MSE: 0.0005, R2: 0.9621
# Internal Surrogate Model Evaluation: - MSE: 0.0010, R2: 0.8930
# Internal Surrogate Model Evaluation: - MSE: 0.0008, R2: 0.8997
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9357
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.8939
# Internal Surrogate Model Evaluation: - MSE: 0.0010, R2: 0.9167
# Internal Surrogate Model Evaluation: - MSE: 0.0008, R2: 0.9416
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9501
# Internal Surrogate Model Evaluation: - MSE: 0.0005, R2: 0.9471
# Internal Surrogate Model Evaluation: - MSE: 0.0007, R2: 0.9467
# Internal Surrogate Model Evaluation: - MSE: 0.0008, R2: 0.8745
# Internal Surrogate Model Evaluation: - MSE: 0.0008, R2: 0.9276
# Internal Surrogate Model Evaluation: - MSE: 0.0007, R2: 0.9395
# Internal Surrogate Model Evaluation: - MSE: 0.0007, R2: 0.9231
# Internal Surrogate Model Evaluation: - MSE: 0.0004, R2: 0.9573
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9470
# Internal Surrogate Model Evaluation: - MSE: 0.0007, R2: 0.9282
# Internal Surrogate Model Evaluation: - MSE: 0.0008, R2: 0.9101
# Random Search:  0.17640000000000086
# SMBO:  0.17640000000000086
# Successive Halving:  0.17640000000000086

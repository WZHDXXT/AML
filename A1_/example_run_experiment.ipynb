# %%
# !pip install ConfigSpace
from google.colab import drive
import argparse
from scipy.stats import spearmanr
import typing
import ConfigSpace
from sklearn.gaussian_process import GaussianProcessRegressor
import matplotlib.pyplot as plt
import numpy as np
from sklearn.gaussian_process.kernels import Matern
import sklearn.impute
import scipy.stats as sps
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.pipeline import Pipeline
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.gaussian_process.kernels import RBF, WhiteKernel,ConstantKernel as C
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

class RandomSearch(object):

    def __init__(self, config_space: ConfigSpace.ConfigurationSpace):
        self.config_space = config_space

    def initialize(self, capital_phi: typing.List[typing.Tuple[typing.Dict, float]]) -> None:
        pass

    def select_configuration(self) -> ConfigSpace.Configuration:
        return self.config_space.sample_configuration(1)

    def update_runs(self, run: typing.Tuple[typing.Dict, float]):
        pass

class SurrogateModel:

    def __init__(self, config_space):
        self.config_space = config_space
        self.df = None
        self.model = None

    def fit(self, df):
        """
        Receives a data frame, in which each column (except for the last two) represents a hyperparameter, the
        penultimate column represents the anchor size, and the final column represents the performance.

        :param df: the dataframe with performances
        :return: Does not return anything, but stores the trained model in self.model
        """
        self.df = df
        x = df.iloc[:, :-1]
        y = df.iloc[:, -1]
        x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
        # fit the external surrogate model using OneHotEncoder
        categorical_features = x.select_dtypes(include=['object']).columns.tolist()
        numerical_features = x.select_dtypes(include=['number']).columns.tolist()
        preprocessor = ColumnTransformer(
            transformers=[
                ('num', sklearn.impute.SimpleImputer(strategy='mean'), numerical_features),
                ('cat', OneHotEncoder(), categorical_features)
            ])

        model = Pipeline(steps=[
            ('preprocessor', preprocessor),
            ('regressor', RandomForestRegressor(n_estimators=1000, random_state=40))
        ])
        model.fit(x_train, y_train)
        self.model = model

        pred = model.predict(x_test)
        mse = mean_squared_error(y_test, pred)
        r2 = r2_score(y_test, pred)
        corr, _ = spearmanr(y_test, pred)
        print(f"External surrogate Model Evaluation: - MSE: {mse:.4f}, R2: {r2:.4f}")
        print(f"Spearman Correlation: {corr:.4f}")


    def predict(self, theta_new):
        """
        Predicts the performance of a given configuration theta_new

        :param theta_new: a dict, where each key represents the hyperparameter (or anchor)
        :return: float, the predicted performance of theta new (which can be considered the ground truth)
        """
        if self.model == None:
            raise ValueError("Train the model first.")
        # fill the keys without full dictionary with default values of the config space
        else:
            for key in dict(self.config_space).keys():
                if key not in theta_new.keys():
                    theta_new[key] = dict(self.config_space)[key].default_value
            list_theta = [theta_new]
            x_test = pd.DataFrame(list_theta)
            x_test = x_test[self.df.keys()[:-1]]
        # predict the performance as ground truth

            y_test = self.model.predict(x_test)
            return y_test[0]

class SequentialModelBasedOptimization(object):

    def __init__(self, config_space):
        """
        Initializes empty variables for the model, the list of runs (capital R), and the incumbent
        (theta_inc being the best found hyperparameters, theta_inc_performance being the performance
        associated with it)
        """
        self.config_space = config_space
        self.R = []
        self.theta_inc = None
        self.theta_inc_performance = None
        self.model = None

    def initialize(self, capital_phi: typing.List[typing.Tuple[typing.Dict, float]]) -> None:
        """
        Initializes the model with a set of initial configurations, before it can make recommendations
        which configurations are in good regions. Note that we are minimising (lower values are preferred)

        :param capital_phi: a list of tuples, each tuple being a configuration and the performance (typically,
        error rate)
        """
        for (c, p) in capital_phi:
            self.R.append((c, p))

            if self.theta_inc is None or p < self.theta_inc_performance:
                self.theta_inc = c
                self.theta_inc_performance = p
    def fit_model(self) -> None:
        """
        Fits the internal surrogate model on the complete run list.
        """
        # key = list(dict(self.config_space).keys())
        Rs = []
        for (c, p) in self.R:
            c = pd.DataFrame([c])
            p = [p]
            p = pd.DataFrame(p, columns=['score'])
            R_ = pd.concat([c, p], axis=1)
            Rs.append(R_)
        df = pd.concat(Rs, axis=0)
        x = df.iloc[:, :-1]
        y = df.iloc[:, -1]

        x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
        categorical_features = x.select_dtypes(include=['object']).columns.tolist()
        numerical_features = x.select_dtypes(include=['number']).columns.tolist()
        preprocessor = ColumnTransformer(
            transformers=[('num',
                           Pipeline([
                               ('imputer', SimpleImputer(strategy='mean')),
                               ('scaler', StandardScaler())
                               ]), numerical_features),
                               ('cat', OneHotEncoder(), categorical_features)
                               ])

        # GaussianProcessRegressor as internal surrogate model
        kernel = C(1.0, (1e-3, 1e3)) * RBF(length_scale=1.0) + WhiteKernel(noise_level=1e-5)
        model = Pipeline(steps=[
            ('preprocessor', preprocessor),
            ('regressor', GaussianProcessRegressor(kernel=kernel, alpha=1e-4,
                                                   normalize_y=True, random_state=40,
                                                   n_restarts_optimizer=30))])
        model.fit(x_train, y_train)
        self.model = model

        pred = self.model.predict(x_test)
        mse = mean_squared_error(y_test, pred)
        r2 = r2_score(y_test, pred)
        print(f"Internal Surrogate Model Evaluation: - MSE: {mse:.4f}, R2: {r2:.4f}")

        self.theta_inc = x.iloc[np.argmin(y)]
        self.theta_inc_performance = y.iloc[np.argmin(y)]

    def select_configuration(self) -> ConfigSpace.Configuration:
        """
        Determines which configurations are good, based on the internal surrogate model.
        Note that we are minimizing the error, but the expected improvement takes into account that.
        Therefore, we are maximizing expected improvement here.

        :return: A size n vector, same size as each element representing the EI of a given
        configuration
        """

        num_candidates = 200
        # smbo.select configuration(sample configurations(many))
        configs = [dict(self.config_space.sample_configuration()) for _ in range(num_candidates)]
        for config in configs:
            for hp in list(self.config_space.values()):
                if hp.name not in config.keys():
                    config[hp.name] = hp.default_value

        configs_df = pd.DataFrame(configs)
        e = self.expected_improvement(self.model, self.theta_inc_performance, configs_df)
        configure = configs[np.argmax(e)]
        return configure

    @staticmethod
    def expected_improvement(model_pipeline: Pipeline, f_star: float, theta: np.array) -> np.array:
        """
        Acquisition function that determines which configurations are good and which
        are not good.

        :param model_pipeline: The internal surrogate model (should be fitted already)
        :param f_star: The current incumbent (theta_inc)
        :param theta: A (n, m) array, each column represents a hyperparameter and each row
        represents a configuration
        :return: A size n vector, same size as each element representing the EI of a given
        configuration
        """
        mu, sigma = model_pipeline.predict(theta, return_std=True)
        sigma = sigma.reshape(-1, 1)
        mu = mu.reshape(-1, 1)

        improvement = f_star - mu

        with np.errstate(divide='warn'):
            Z = np.where(sigma > 0, improvement / sigma, 0)
            ei = improvement * sps.norm.cdf(Z) + sigma * sps.norm.pdf(Z)
            ei[sigma == 0.0] == 0.0
        return ei.ravel()

    def update_runs(self, run: typing.Tuple[typing.Dict, float]):
        """
        After a configuration has been selected and ran, it will be added to the run list
        (so that the model can be trained on it during the next iterations).

        :param run: A tuple (configuration, performance) where performance is error rate
        """
        (c, p) = run

        self.R.append((c, p))

        if p < self.theta_inc_performance:
            self.theta_inc = c
            self.theta_inc_performance = p



def parse_args():
    parser = argparse.ArgumentParser()
    parser.add_argument('--config_space_file', type=str, default='/content/drive/MyDrive/lcdb_config_space_knn.json')
    parser.add_argument('--configurations_performance_file', type=str, default='lcdb_configs.csv')
    parser.add_argument('--configurations_performance_file_1', type=str, default='config_performances_dataset-6.csv')
    parser.add_argument('--configurations_performance_file_2', type=str, default='config_performances_dataset-11.csv')
    parser.add_argument('--configurations_performance_file_3', type=str, default='config_performances_dataset-1457.csv')
    # max_anchor_size: connected to the configurations_performance_file. The max value upon which anchors are sampled
    parser.add_argument('--max_anchor_size', type=int, default=1600)
    parser.add_argument('--num_iterations', type=int, default=50)

    return parser.parse_known_args()[0]


def run(args):
    config_space = ConfigSpace.ConfigurationSpace.from_json(args.config_space_file)
    df_list = []
    df_1 = pd.read_csv(args.configurations_performance_file)
    df_2 = pd.read_csv(args.configurations_performance_file_1)
    df_3 = pd.read_csv(args.configurations_performance_file_2)
    df_4 = pd.read_csv(args.configurations_performance_file_3)
    df_list.append(df_1)
    df_list.append(df_2)
    df_list.append(df_3)
    df_list.append(df_4)
    # df = pd.read_csv(args.configurations_performance_file)
    for df in df_list:
        # successive halving
        halving_factor = 2
        surrogate_model_halving = SurrogateModel(config_space)
        surrogate_model_halving.fit(df)

        results = {
            'successive halving': [1.0]
        }
        best_performance = []
        best = np.inf
        for idx in range(args.num_iterations):
            total_anchor = [0]
            total_performance = {}

            # anchor size to be 10% of data
            current_anchor = 25
            configs = [dict(config_space.sample_configuration()) for _ in range(64)]
            while(current_anchor<=args.max_anchor_size):
                total_anchor.append(current_anchor)
                performances = []
                m = len(configs)

                for config in configs:
                    for hp in list(config_space.values()):
                        if hp.name not in config.keys():
                            config[hp.name] = hp.default_value
                    config['anchor_size'] = current_anchor

                    performance = surrogate_model_halving.predict(config)
                    performances.append(performance)

                total_performance['M'+str(current_anchor)] = performances
                performances = np.array(performances)
                performances_sorted = np.argsort(performances)
                num = int(m/halving_factor)

                configs = [configs[index] for index in performances_sorted[:num]]
                current_anchor *= halving_factor
            p = total_performance.get(list(total_performance.keys())[-1])[0]
            if p < best:
                best = p
                best_performance.append(total_performance)

            results['successive halving'].append(min(results['successive halving'][-1], best))


        # random search
        random_search = RandomSearch(config_space)
        surrogate_model_random = SurrogateModel(config_space)
        surrogate_model_random.fit(df)

        results_randomsearch = {
            'random_search': [1.0]
        }

        for idx in range(args.num_iterations):
            theta_new = dict(random_search.select_configuration())
            theta_new['anchor_size'] = args.max_anchor_size
            performance = surrogate_model_random.predict(theta_new)
            # ensure to only record improvements
            results_randomsearch['random_search'].append(min(results_randomsearch['random_search'][-1], performance))
            random_search.update_runs((theta_new, performance))
        print('random search', min(results_randomsearch['random_search']))

        # smbo
        surrogate_model_smbo = SurrogateModel(config_space)
        surrogate_model_smbo.fit(df)

        smbo = SequentialModelBasedOptimization(config_space)
        initial_runs = []

        configs = [dict(config_space.sample_configuration()) for _ in range(200)]
        for config in configs:
            config['anchor_size'] = args.max_anchor_size
            config['score'] = surrogate_model_smbo.predict(config)
        '''configs = sorted(configs, key=lambda e: e.__getitem__('score'))
        configs = configs[:100]'''
        configs_ = configs.copy()
        for c in configs_:
            c = c.pop('anchor_size')
        variables = list(df.keys())
        variables.remove('anchor_size')
        df_config = pd.DataFrame([[i[j] for j in variables] for i in configs_], columns=variables)
        m, n = df_config.shape

        for _, row in df_config.iterrows():
            config = dict(row.head(n-1))
            p = row['score']
            initial_runs.append((config, p))
        smbo.initialize(initial_runs)

        results_BO = {
            'BO': [1.0]
            }

        for idx in range(args.num_iterations):
            smbo.fit_model()
            theta_new = smbo.select_configuration()
            theta_new['anchor_size'] = args.max_anchor_size
            theta_new_ = theta_new.copy()
            performance = surrogate_model_smbo.predict(theta_new)
            del theta_new_['anchor_size']
            results_BO['BO'].append(min(results_BO['BO'][-1], performance))
            # results_BO['BO'].append(min(results_BO['BO'][-1], performance))
            smbo.update_runs((theta_new_, performance))

        print("results BO", min(results_BO['BO']))

        plt.plot(range(len(results_randomsearch['random_search'])), results_randomsearch['random_search'], color='blue', label='random search')
        plt.plot(range(len(results['successive halving'])), results['successive halving'], color='red', label='successive halving')
        plt.plot(range(len(results_BO['BO'])), results_BO['BO'], color='green', label='smbo')
        plt.legend()

        plt.yscale('log')
        plt.show()


if __name__ == '__main__':
    run(parse_args())
# Out:
# Collecting ConfigSpace
#   Downloading configspace-1.2.0.tar.gz (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.8/130.8 kB 2.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from ConfigSpace) (1.26.4)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.10/dist-packages (from ConfigSpace) (3.1.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from ConfigSpace) (1.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from ConfigSpace) (4.12.2)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from ConfigSpace) (10.5.0)
# Building wheels for collected packages: ConfigSpace
#   Building wheel for ConfigSpace (pyproject.toml) ... done
#   Created wheel for ConfigSpace: filename=ConfigSpace-1.2.0-py3-none-any.whl size=115855 sha256=9790c2fa0409fe89ca29b2d937888c82f37bc89c8bc40deb63faf6e2b0599968
#   Stored in directory: /root/.cache/pip/wheels/5f/1f/4b/450c9c9d1ede888e354984d9eba7e60f13878fa079d502d52e
# Successfully built ConfigSpace
# Installing collected packages: ConfigSpace
# Successfully installed ConfigSpace-1.2.0
# Mounted at /content/drive/
# External surrogate Model Evaluation: - MSE: 0.0004, R2: 0.9914
# Spearman Correlation: 0.9965
# External surrogate Model Evaluation: - MSE: 0.0004, R2: 0.9926
# Spearman Correlation: 0.9955
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# random search 0.15478440000000032
# External surrogate Model Evaluation: - MSE: 0.0007, R2: 0.9854
# Spearman Correlation: 0.9948
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.4914
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.3868
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.6838
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.5516
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.4647
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.2350
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.5915
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.6206
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.7720
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.6543
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.7349
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.7086
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.5869
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.2890
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.7047
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.1008
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.6917
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.5353
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.5041
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.6339
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.7249
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.5261
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.4439
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.3118
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.4596
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.5540
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.6405
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.6073
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.7416
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.6762
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.6322
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.6577
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.6667
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.6094
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.5256
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.5655
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.5242
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.6867
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.4809
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.2749
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.4131
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.4239
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.4601
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.7563
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.5597
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.5811
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.4641
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.4849
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.3672
# Internal Surrogate Model Evaluation: - MSE: 0.0001, R2: 0.5799
# results BO 0.15378279999999936
# External surrogate Model Evaluation: - MSE: 0.0000, R2: 0.9997
# Spearman Correlation: 0.9998
# External surrogate Model Evaluation: - MSE: 0.0000, R2: 0.9997
# Spearman Correlation: 0.9998
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# random search 0.17642640000000084
# External surrogate Model Evaluation: - MSE: 0.0000, R2: 0.9997
# Spearman Correlation: 0.9998
# Internal Surrogate Model Evaluation: - MSE: 0.0008, R2: 0.8651
# Internal Surrogate Model Evaluation: - MSE: 0.0012, R2: 0.8824
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9428
# Internal Surrogate Model Evaluation: - MSE: 0.0007, R2: 0.9049
# Internal Surrogate Model Evaluation: - MSE: 0.0010, R2: 0.8709
# Internal Surrogate Model Evaluation: - MSE: 0.0007, R2: 0.9159
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9528
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9434
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9287
# Internal Surrogate Model Evaluation: - MSE: 0.0008, R2: 0.9063
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9179
# Internal Surrogate Model Evaluation: - MSE: 0.0007, R2: 0.9088
# Internal Surrogate Model Evaluation: - MSE: 0.0008, R2: 0.9160
# Internal Surrogate Model Evaluation: - MSE: 0.0007, R2: 0.9368
# Internal Surrogate Model Evaluation: - MSE: 0.0005, R2: 0.9465
# Internal Surrogate Model Evaluation: - MSE: 0.0007, R2: 0.9263
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9334
# Internal Surrogate Model Evaluation: - MSE: 0.0008, R2: 0.9170
# Internal Surrogate Model Evaluation: - MSE: 0.0007, R2: 0.9275
# Internal Surrogate Model Evaluation: - MSE: 0.0007, R2: 0.9345
# Internal Surrogate Model Evaluation: - MSE: 0.0008, R2: 0.9158
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9436
# Internal Surrogate Model Evaluation: - MSE: 0.0008, R2: 0.9120
# Internal Surrogate Model Evaluation: - MSE: 0.0003, R2: 0.9662
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9426
# Internal Surrogate Model Evaluation: - MSE: 0.0007, R2: 0.8798
# Internal Surrogate Model Evaluation: - MSE: 0.0007, R2: 0.9269
# Internal Surrogate Model Evaluation: - MSE: 0.0007, R2: 0.9218
# Internal Surrogate Model Evaluation: - MSE: 0.0007, R2: 0.9392
# Internal Surrogate Model Evaluation: - MSE: 0.0007, R2: 0.9426
# Internal Surrogate Model Evaluation: - MSE: 0.0005, R2: 0.9397
# Internal Surrogate Model Evaluation: - MSE: 0.0007, R2: 0.9360
# Internal Surrogate Model Evaluation: - MSE: 0.0007, R2: 0.9268
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9424
# Internal Surrogate Model Evaluation: - MSE: 0.0008, R2: 0.9136
# Internal Surrogate Model Evaluation: - MSE: 0.0004, R2: 0.9608
# Internal Surrogate Model Evaluation: - MSE: 0.0007, R2: 0.9442
# Internal Surrogate Model Evaluation: - MSE: 0.0005, R2: 0.9558
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9371
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9194
# Internal Surrogate Model Evaluation: - MSE: 0.0008, R2: 0.8979
# Internal Surrogate Model Evaluation: - MSE: 0.0005, R2: 0.9507
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9267
# Internal Surrogate Model Evaluation: - MSE: 0.0004, R2: 0.9257
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9440
# Internal Surrogate Model Evaluation: - MSE: 0.0005, R2: 0.9635
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9401
# Internal Surrogate Model Evaluation: - MSE: 0.0004, R2: 0.9600
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9371
# Internal Surrogate Model Evaluation: - MSE: 0.0005, R2: 0.9416
# results BO 0.17640000000000086
# External surrogate Model Evaluation: - MSE: 0.0000, R2: 0.9983
# Spearman Correlation: 0.9981
# External surrogate Model Evaluation: - MSE: 0.0000, R2: 0.9974
# Spearman Correlation: 0.9982
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# random search 0.029338709677418844
# External surrogate Model Evaluation: - MSE: 0.0000, R2: 0.9984
# Spearman Correlation: 0.9980
# Internal Surrogate Model Evaluation: - MSE: 0.0021, R2: 0.6765
# Internal Surrogate Model Evaluation: - MSE: 0.0020, R2: 0.5686
# Internal Surrogate Model Evaluation: - MSE: 0.0020, R2: 0.5978
# Internal Surrogate Model Evaluation: - MSE: 0.0017, R2: 0.7123
# Internal Surrogate Model Evaluation: - MSE: 0.0018, R2: 0.7471
# Internal Surrogate Model Evaluation: - MSE: 0.0022, R2: 0.6230
# Internal Surrogate Model Evaluation: - MSE: 0.0020, R2: 0.5992
# Internal Surrogate Model Evaluation: - MSE: 0.0022, R2: 0.6198
# Internal Surrogate Model Evaluation: - MSE: 0.0018, R2: 0.4794
# Internal Surrogate Model Evaluation: - MSE: 0.0026, R2: 0.5189
# Internal Surrogate Model Evaluation: - MSE: 0.0023, R2: 0.6615
# Internal Surrogate Model Evaluation: - MSE: 0.0014, R2: 0.6925
# Internal Surrogate Model Evaluation: - MSE: 0.0018, R2: 0.6034
# Internal Surrogate Model Evaluation: - MSE: 0.0017, R2: 0.7368
# Internal Surrogate Model Evaluation: - MSE: 0.0020, R2: 0.6888
# Internal Surrogate Model Evaluation: - MSE: 0.0018, R2: 0.6477
# Internal Surrogate Model Evaluation: - MSE: 0.0029, R2: 0.6271
# Internal Surrogate Model Evaluation: - MSE: 0.0014, R2: 0.7139
# Internal Surrogate Model Evaluation: - MSE: 0.0017, R2: 0.6995
# Internal Surrogate Model Evaluation: - MSE: 0.0024, R2: 0.5254
# Internal Surrogate Model Evaluation: - MSE: 0.0014, R2: 0.7252
# Internal Surrogate Model Evaluation: - MSE: 0.0012, R2: 0.7651
# Internal Surrogate Model Evaluation: - MSE: 0.0025, R2: 0.5700
# Internal Surrogate Model Evaluation: - MSE: 0.0020, R2: 0.6688
# Internal Surrogate Model Evaluation: - MSE: 0.0020, R2: 0.6023
# Internal Surrogate Model Evaluation: - MSE: 0.0017, R2: 0.5928
# Internal Surrogate Model Evaluation: - MSE: 0.0022, R2: 0.6413
# Internal Surrogate Model Evaluation: - MSE: 0.0014, R2: 0.6294
# Internal Surrogate Model Evaluation: - MSE: 0.0030, R2: 0.5328
# Internal Surrogate Model Evaluation: - MSE: 0.0017, R2: 0.7174
# Internal Surrogate Model Evaluation: - MSE: 0.0025, R2: 0.6521
# Internal Surrogate Model Evaluation: - MSE: 0.0018, R2: 0.6847
# Internal Surrogate Model Evaluation: - MSE: 0.0018, R2: 0.6891
# Internal Surrogate Model Evaluation: - MSE: 0.0016, R2: 0.7187
# Internal Surrogate Model Evaluation: - MSE: 0.0032, R2: 0.5005
# Internal Surrogate Model Evaluation: - MSE: 0.0012, R2: 0.8122
# Internal Surrogate Model Evaluation: - MSE: 0.0021, R2: 0.7134
# Internal Surrogate Model Evaluation: - MSE: 0.0022, R2: 0.7016
# Internal Surrogate Model Evaluation: - MSE: 0.0013, R2: 0.7069
# Internal Surrogate Model Evaluation: - MSE: 0.0018, R2: 0.7482
# Internal Surrogate Model Evaluation: - MSE: 0.0020, R2: 0.7237
# Internal Surrogate Model Evaluation: - MSE: 0.0016, R2: 0.7283
# Internal Surrogate Model Evaluation: - MSE: 0.0014, R2: 0.6873
# Internal Surrogate Model Evaluation: - MSE: 0.0017, R2: 0.7015
# Internal Surrogate Model Evaluation: - MSE: 0.0015, R2: 0.7543
# Internal Surrogate Model Evaluation: - MSE: 0.0016, R2: 0.6980
# Internal Surrogate Model Evaluation: - MSE: 0.0016, R2: 0.7809
# Internal Surrogate Model Evaluation: - MSE: 0.0011, R2: 0.7831
# Internal Surrogate Model Evaluation: - MSE: 0.0018, R2: 0.6853
# Internal Surrogate Model Evaluation: - MSE: 0.0016, R2: 0.7775
# results BO 0.029232258064515536
# External surrogate Model Evaluation: - MSE: 0.0001, R2: 0.9959
# Spearman Correlation: 0.9887
# External surrogate Model Evaluation: - MSE: 0.0001, R2: 0.9958
# Spearman Correlation: 0.9924
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# <ipython-input-1-743cc445984b>:37: DeprecationWarning: Please leave at default or explicitly set `size=None`. In the future, specifying a size will always return a list, even if 1
#   return self.config_space.sample_configuration(1)
# random search 0.5335153333333273
# External surrogate Model Evaluation: - MSE: 0.0000, R2: 0.9966
# Spearman Correlation: 0.9907
# Internal Surrogate Model Evaluation: - MSE: 0.0017, R2: 0.7622
# Internal Surrogate Model Evaluation: - MSE: 0.0007, R2: 0.9097
# Internal Surrogate Model Evaluation: - MSE: 0.0005, R2: 0.9407
# Internal Surrogate Model Evaluation: - MSE: 0.0009, R2: 0.8663
# Internal Surrogate Model Evaluation: - MSE: 0.0005, R2: 0.9325
# Internal Surrogate Model Evaluation: - MSE: 0.0020, R2: 0.7513
# Internal Surrogate Model Evaluation: - MSE: 0.0013, R2: 0.8778
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9118
# Internal Surrogate Model Evaluation: - MSE: 0.0005, R2: 0.9392
# Internal Surrogate Model Evaluation: - MSE: 0.0005, R2: 0.9534
# Internal Surrogate Model Evaluation: - MSE: 0.0009, R2: 0.8807
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9207
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9589
# Internal Surrogate Model Evaluation: - MSE: 0.0009, R2: 0.8600
# Internal Surrogate Model Evaluation: - MSE: 0.0007, R2: 0.9336
# Internal Surrogate Model Evaluation: - MSE: 0.0009, R2: 0.8943
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9202
# Internal Surrogate Model Evaluation: - MSE: 0.0008, R2: 0.9217
# Internal Surrogate Model Evaluation: - MSE: 0.0009, R2: 0.9252
# Internal Surrogate Model Evaluation: - MSE: 0.0007, R2: 0.9385
# Internal Surrogate Model Evaluation: - MSE: 0.0013, R2: 0.8757
# Internal Surrogate Model Evaluation: - MSE: 0.0012, R2: 0.8767
# Internal Surrogate Model Evaluation: - MSE: 0.0009, R2: 0.9316
# Internal Surrogate Model Evaluation: - MSE: 0.0007, R2: 0.9433
# Internal Surrogate Model Evaluation: - MSE: 0.0008, R2: 0.9205
# Internal Surrogate Model Evaluation: - MSE: 0.0014, R2: 0.8890
# Internal Surrogate Model Evaluation: - MSE: 0.0007, R2: 0.9365
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9567
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9465
# Internal Surrogate Model Evaluation: - MSE: 0.0008, R2: 0.9436
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9301
# Internal Surrogate Model Evaluation: - MSE: 0.0008, R2: 0.9164
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9523
# Internal Surrogate Model Evaluation: - MSE: 0.0004, R2: 0.9544
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9399
# Internal Surrogate Model Evaluation: - MSE: 0.0008, R2: 0.9147
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9556
# Internal Surrogate Model Evaluation: - MSE: 0.0005, R2: 0.9520
# Internal Surrogate Model Evaluation: - MSE: 0.0004, R2: 0.9680
# Internal Surrogate Model Evaluation: - MSE: 0.0012, R2: 0.9073
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9521
# Internal Surrogate Model Evaluation: - MSE: 0.0007, R2: 0.9407
# Internal Surrogate Model Evaluation: - MSE: 0.0006, R2: 0.9386
# Internal Surrogate Model Evaluation: - MSE: 0.0009, R2: 0.9322
# Internal Surrogate Model Evaluation: - MSE: 0.0004, R2: 0.9621
# Internal Surrogate Model Evaluation: - MSE: 0.0009, R2: 0.9372
# Internal Surrogate Model Evaluation: - MSE: 0.0009, R2: 0.8982
# Internal Surrogate Model Evaluation: - MSE: 0.0007, R2: 0.9060
# Internal Surrogate Model Evaluation: - MSE: 0.0008, R2: 0.9301
# Internal Surrogate Model Evaluation: - MSE: 0.0005, R2: 0.9642
# results BO 0.5152693333333266
